# %%
import requests
path="/api/event"
base_url="http://localhost:8002"
endpoint=f"{base_url}{path}"
endpoint
# Out:
# 'http://localhost:8002/api/event'

# %%
response=requests.get(endpoint)
print(response.ok)
# Out:
# True

# %%
if response.ok:
    data=response.json()
    print(data)
# Out:
# [{'bucket': '2026-03-18T21:19:10Z', 'page': '/about', 'count': 25}, {'bucket': '2026-03-18T21:19:10Z', 'page': '/contact', 'count': 21}, {'bucket': '2026-03-18T21:19:10Z', 'page': '/pages', 'count': 14}, {'bucket': '2026-03-18T21:19:10Z', 'page': '/pricing', 'count': 27}, {'bucket': '2026-03-18T21:19:20Z', 'page': '/about', 'count': 34}, {'bucket': '2026-03-18T21:19:20Z', 'page': '/contact', 'count': 36}, {'bucket': '2026-03-18T21:19:20Z', 'page': '/pages', 'count': 36}, {'bucket': '2026-03-18T21:19:20Z', 'page': '/pricing', 'count': 47}, {'bucket': '2026-03-18T21:19:30Z', 'page': '/about', 'count': 37}, {'bucket': '2026-03-18T21:19:30Z', 'page': '/contact', 'count': 31}, {'bucket': '2026-03-18T21:19:30Z', 'page': '/pages', 'count': 39}, {'bucket': '2026-03-18T21:19:30Z', 'page': '/pricing', 'count': 38}, {'bucket': '2026-03-18T21:19:40Z', 'page': '/about', 'count': 39}, {'bucket': '2026-03-18T21:19:40Z', 'page': '/contact', 'count': 36}, {'bucket': '2026-03-18T21:19:40Z', 'page': '/
# ...
