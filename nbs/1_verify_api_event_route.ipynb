# %%
import requests
path="/api/event/12"
base_url="http://localhost:8000"
endpoint=f"{base_url}{path}"
endpoint
# Out:
# 'http://localhost:8000/api/event/12'

# %%
response=requests.get(endpoint)
print(response.ok)
# Out:
# False

# %%
if response.ok:
    data=response.json()
    print(data, type(data), data.get('item'))
